# %%
    LIST_NOTE = [
        {"path": "/Workspace/Users/duythinh331@gmail.com/databrick-data-lakehouse-project/gold/gold_dim_customer","timeout": 600, "name": "gold_dim_customer"},
        {"path": "/Workspace/Users/duythinh331@gmail.com/databrick-data-lakehouse-project/gold/gold_dim_product","timeout": 600, "name": "gold_dim_product"},
        {"path": "/Workspace/Users/duythinh331@gmail.com/databrick-data-lakehouse-project/gold/gold_fact_sales","timeout": 600, "name": "gold_fact_sales"}
    ]
    for nb in LIST_NOTE:
        try:
            print(f"Đang xử lý: {nb['name']} ({nb['path']})...")
            dbutils.notebook.run(nb['path'], nb['timeout'])
        except Exception as e:
            print(f"PIPELINE THẤT BẠI! Chi tiết lỗi: {e}")
