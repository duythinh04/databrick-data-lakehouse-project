# %%
    LIST_NOTE = [
        {"path": "/Workspace/Users/duythinh331@gmail.com/databrick-data-lakehouse-project/silver/sillver_log_a101","timeout": 600, "name": "sillver_log_a101"},
        {"path": "/Workspace/Users/duythinh331@gmail.com/databrick-data-lakehouse-project/silver/silver_cust_az12","timeout": 600, "name": "silver_cust_az12"},
        {"path": "/Workspace/Users/duythinh331@gmail.com/databrick-data-lakehouse-project/silver/silver_cust_info","timeout": 600, "name": "silver_cust_info"},
        {"path": "/Workspace/Users/duythinh331@gmail.com/databrick-data-lakehouse-project/silver/silver_prd_info","timeout": 600, "name": "silver_prd_info"},
        {"path": "/Workspace/Users/duythinh331@gmail.com/databrick-data-lakehouse-project/silver/silver_px_cat_g1v2","timeout": 600, "name": "silver_px_cat_g1v2"},
        {"path": "/Workspace/Users/duythinh331@gmail.com/databrick-data-lakehouse-project/silver/silver_sale_details","timeout": 600, "name": "silver_sale_details"}
    ]
    for nb in LIST_NOTE:
        try:
            print(f"Đang xử lý: {nb['name']} ({nb['path']})...")
            dbutils.notebook.run(nb['path'], nb['timeout'])
        except Exception as e:
            print(f"PIPELINE THẤT BẠI! Chi tiết lỗi: {e}")
